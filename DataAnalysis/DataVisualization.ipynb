# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('data/matches.csv')

# %%
# plt.hist(dataset['win_by_wickets'])

plt.hist(dataset['season'], rwidth=0.9)
plt.show()

# %%
sns.countplot(x='season', data=dataset)
plt.show()

# %%
# plt.figure - used to set height and width of graph
plt.figure(figsize=(12,6))
sns.countplot(x='winner', data=dataset)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(x='toss_decision', data=dataset)
plt.show()

# %%
toss_decision = pd.value_counts(dataset['toss_decision'])

# %%
toss_decision
# Out:
# field    315
# bat      262
# Name: toss_decision, dtype: int64

# %%
labels = np.array(['bat','field'])

# %%
x = np.array([262,315])

# %%
plt.pie(x, labels=labels, startangle=90, autopct='%1.1f%%')
plt.show()
