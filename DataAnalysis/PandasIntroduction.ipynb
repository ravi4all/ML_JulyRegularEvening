# %%
# Numpy
# Pandas
# Matploitlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Pandas

# %%
# Series        - 1D - list/tuples/dict
# Dataframe     - 2D - array/matrix/
# Panel         - More than 2D

# %%
movieRatings = np.array([5,4,5,3,4,2,4,5,3,1,2,4,5,3,3])
series = pd.Series(movieRatings)

# %%
series
# Out:
# 0     5
# 1     4
# 2     5
# 3     3
# 4     4
# 5     2
# 6     4
# 7     5
# 8     3
# 9     1
# 10    2
# 11    4
# 12    5
# 13    3
# 14    3
# dtype: int32

# %%
series[0:5]
# Out:
# 0    5
# 1    4
# 2    5
# 3    3
# 4    4
# dtype: int32

# %%
# filter
# series > 4
# series == 4
series[series >= 4]
# Out:
# 0     5
# 1     4
# 2     5
# 4     4
# 6     4
# 7     5
# 11    4
# 12    5
# dtype: int32

# %%
movieName = ['Avengers','Antman','Sanju','Baahubali','Don','Sholay','Fukrey','Robot']
moveiRatings = [5,4,4,5,4,5,3,5]

movies = {
    'movieName' : movieName,
    'ratings' : moveiRatings
}

# %%
df = pd.DataFrame(movies)

# %%
df
# Out:
#    movieName  ratings
# 0   Avengers        5
# 1     Antman        4
# 2      Sanju        4
# 3  Baahubali        5
# 4        Don        4
# 5     Sholay        5
# 6     Fukrey        3
# 7      Robot        5

# %%
df[df['ratings'] == 5]
# Out:
#    movieName  ratings
# 0   Avengers        5
# 3  Baahubali        5
# 5     Sholay        5
# 7      Robot        5

# %%
# df.sort_values('ratings')
df.sort_values('ratings', ascending=False)
# Out:
#    movieName  ratings
# 0   Avengers        5
# 3  Baahubali        5
# 5     Sholay        5
# 7      Robot        5
# 1     Antman        4
# 2      Sanju        4
# 4        Don        4
# 6     Fukrey        3

# %% [markdown]
# # File I/O

# %%
dataset = pd.read_csv('data/matches.csv')

# %%
dataset.shape
# Out:
# (577, 18)

# %%
# will return top 5 observations
# dataset.head()

dataset.head(8)
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
# 5   6    2008      Jaipur  2008-04-21        Kings XI Punjab
# 6   7    2008   Hyderabad  2008-04-22        Deccan Chargers
# 7   8    2008     Chennai  2008-04-23    Chennai Super Kings
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# ...

# %%
# will return bottom 5 observations
dataset.tail()
# Out:
#       id  season       city        date                team1  \
# 572  573    2016     Raipur  2016-05-22     Delhi Daredevils
# 573  574    2016  Bangalore  2016-05-24        Gujarat Lions
# 574  575    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 575  576    2016      Delhi  2016-05-27        Gujarat Lions
# 576  577    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 572  normal           0  Royal Challengers Bangalore            0
# ...

# %%
# used for slicing
dataset.iloc[0:5,4:8]
# Out:
#                    team1                        team2  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore
# 1    Chennai Super Kings              Kings XI Punjab
# 2       Rajasthan Royals             Delhi Daredevils
# 3         Mumbai Indians  Royal Challengers Bangalore
# 4        Deccan Chargers        Kolkata Knight Riders
#
#                    toss_winner toss_decision
# 0  Royal Challengers Bangalore         field
# 1          Chennai Super Kings           bat
# 2             Rajasthan Royals           bat
# 3               Mumbai Indians           bat
# 4              Deccan Chargers           bat

# %%
dataset.iloc[0:5, [2,4,5,10]]
# Out:
#          city                  team1                        team2  \
# 0   Bangalore  Kolkata Knight Riders  Royal Challengers Bangalore
# 1  Chandigarh    Chennai Super Kings              Kings XI Punjab
# 2       Delhi       Rajasthan Royals             Delhi Daredevils
# 3      Mumbai         Mumbai Indians  Royal Challengers Bangalore
# 4     Kolkata        Deccan Chargers        Kolkata Knight Riders
#
#                         winner
# 0        Kolkata Knight Riders
# 1          Chennai Super Kings
# 2             Delhi Daredevils
# 3  Royal Challengers Bangalore
# 4        Kolkata Knight Riders

# %%
# statistical analysis of any data
dataset.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  577.000000   577.000000  577.000000   577.000000      577.000000
# mean   289.000000  2012.029463    0.025997    13.715771        3.363951
# std    166.709828     2.486247    0.159263    23.619282        3.416049
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    145.000000  2010.000000    0.000000     0.000000        0.000000
# 50%    289.000000  2012.000000    0.000000     0.000000        3.000000
# 75%    433.000000  2014.000000    0.000000    20.000000        6.000000
# max    577.000000  2016.000000    1.000000   144.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
# axis = 0 - row wise
# axis = 1 - column wise
dataset.dropna(axis=1, inplace=True)

# %%
dataset.head()
# Out:
#    id  season        date                  team1                        team2  \
# 0   1    2008  2008-04-18  Kolkata Knight Riders  Royal Challengers Bangalore
# 1   2    2008  2008-04-19    Chennai Super Kings              Kings XI Punjab
# 2   3    2008  2008-04-19       Rajasthan Royals             Delhi Daredevils
# 3   4    2008  2008-04-20         Mumbai Indians  Royal Challengers Bangalore
# 4   5    2008  2008-04-20        Deccan Chargers        Kolkata Knight Riders
#
#                    toss_winner toss_decision  result  dl_applied  win_by_runs  \
# 0  Royal Challengers Bangalore         field  normal           0          140
# 1          Chennai Super Kings           bat  normal           0           33
# 2             Rajasthan Royals           bat  normal           0            0
# 3               Mumbai Indians           bat  normal           0            0
# 4              Deccan Chargers           bat  normal           0            0
#
# ...

# %%
dataset.drop_duplicates('season', keep='last')[['season','winner']]
# Out:
#      season                 winner
# 57     2008       Rajasthan Royals
# 114    2009        Deccan Chargers
# 174    2010    Chennai Super Kings
# 247    2011    Chennai Super Kings
# 321    2012  Kolkata Knight Riders
# 397    2013         Mumbai Indians
# 457    2014  Kolkata Knight Riders
# 516    2015         Mumbai Indians
# 576    2016    Sunrisers Hyderabad

# %%
temp_df = dataset[(dataset['player_of_match'] == 'MS Dhoni') & (dataset['toss_decision'] == 'bat')]

# %%
temp_df.iloc[:,[4,5,6,7,10]]
# Out:
#                    team1                        team2          toss_winner  \
# 14   Chennai Super Kings  Royal Challengers Bangalore  Chennai Super Kings
# 84   Chennai Super Kings              Deccan Chargers  Chennai Super Kings
# 122  Chennai Super Kings        Kolkata Knight Riders  Chennai Super Kings
# 229  Chennai Super Kings             Delhi Daredevils  Chennai Super Kings
# 354  Sunrisers Hyderabad          Chennai Super Kings  Sunrisers Hyderabad
# 362  Chennai Super Kings                Pune Warriors  Chennai Super Kings
# 386  Chennai Super Kings             Delhi Daredevils  Chennai Super Kings
# 569      Kings XI Punjab      Rising Pune Supergiants      Kings XI Punjab
#
#     toss_decision                   winner
# 14            bat      Chennai Super Kings
# 84            bat      Chennai Super Kings
# 122           bat      Chennai Super Kings
# 229           bat      Chennai Super Kings
# 354           bat      Chennai Super Kings
# ...
